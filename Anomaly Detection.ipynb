# %% [markdown]
# # Anomaly Detection

# %% [markdown]
# ## Isolation Forest
#
# Isolation forest is a machine learning algorithm for anomaly detection.
# It's an unsupervised learning algorithm that identifies anomaly by isolating outliers in the data.
#
# Isolation Forest is based on the Decision Tree algorithm. It isolates the outliers by randomly selecting a feature from the given set of features and then randomly selecting a split value between the max and min values of that feature. This random partitioning of features will produce shorter paths in trees for the anomalous data points, thus distinguishing them from the rest of the data.
#
# In general the first step to anomaly detection is to construct a profile of what's "normal", and then report anything that cannot be considered normal as anomalous. However, the isolation forest algorithm does not work on this principle; it does not first define "normal" behavior, and it does not calculate point-based distances.
#
# https://blog.paperspace.com/anomaly-detection-isolation-forest/

# %%
from sklearn.ensemble import IsolationForest

model_IF = IsolationForest(contamination=float(0.5), random_state=42)
model_IF.fit(X_train)

isolated = X_train.copy()
isolated['anomaly_scores'] = model_IF.decision_function(X_train)
isolated['anomaly'] = model_IF.predict(X_train)
isolated.head()
# Out:
# C:\Users\cliff\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
#         duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 484230         0              1       21     1          0          0     0
# 140849         0              1       36     1          0          0     0
# 343141         0              2       40     9        105        146     0
# 26168          0              1       21     9        206       7355     0
# 139864         0              1       21     9        289       1959     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 484230               0       0    0  ...                    1.00
# 140849               0       0    0  ...                    0.00
# 343141               0       0    0  ...                    0.96
# 26168                0       0    0  ...                    1.00
# ...

# %%
# Print out key statistics
print(f"Number of anomalous values {len(isolated[isolated['anomaly']==-1])}")
print(f"Number of non anomalous values  {len(isolated[isolated['anomaly']== 1])}")
print(f'Total Number of Values: {len(isolated)}')
# Out:
# Number of anomalous values 41608
# Number of non anomalous values  41608
# Total Number of Values: 83216

# %%
isolated['outcome'] = y_train

# %%
isolated[isolated['anomaly']==  -1].head()
# Out:
#         duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 484230         0              1       21     1          0          0     0
# 140849         0              1       36     1          0          0     0
# 343141         0              2       40     9        105        146     0
# 344072         0              1       21     1          0          0     0
# 143495         0              2       10     9         36         96     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 484230               0       0    0  ...                    0.00
# 140849               0       0    0  ...                    1.00
# 343141               0       0    0  ...                    0.01
# 344072               0       0    0  ...                    0.00
# 143495               0       0    0  ...                    0.02
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# ...

# %%
isolated[isolated['anomaly']==  -1]['outcome'].value_counts().sort_index()
# Out:
# 0     1183
# 1    36216
# 2     3265
# 3      901
# 4       43
# Name: outcome, dtype: int64

# %% [markdown]
# ### Categories of Attacks
#
# * 0 - DOS: Denial of Service
# * 1 - Normal
# * 2 - probing (Brute-force probing attacks)
# * 3 - R2L (Unauthorized accesses from remote servers)
# * 4 - U2R (Privilege escalation attempts): Exploitation of vulnerabilities such as software bugs, misconfigurations, and incorrect access controls
#
# https://kdd.ics.uci.edu/databases/kddcup99/task.html

# %%
isolated[isolated['anomaly']==  1].head()
# Out:
#         duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 26168          0              1       21     9        206       7355     0
# 139864         0              1       21     9        289       1959     0
# 7100           0              1       21     9        331        612     0
# 107287         0              1       21     9        346      11319     0
# 15366          0              1       21     9        206        945     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 26168                0       0    0  ...                     0.0
# 139864               0       0    0  ...                     0.0
# 7100                 0       0    0  ...                     0.0
# 107287               0       0    0  ...                     0.0
# 15366                0       0    0  ...                     0.0
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# ...

# %%
isolated[isolated['anomaly']==  1]['outcome'].value_counts().sort_index()
# Out:
# 1    41608
# Name: outcome, dtype: int64

# %% [markdown]
# ### Categories of Attacks
#
# * 0 - DOS: Denial of Service
# * 1 - Normal
# * 2 - probing (Brute-force probing attacks)
# * 3 - R2L (Unauthorized accesses from remote servers)
# * 4 - U2R (Privilege escalation attempts): Exploitation of vulnerabilities such as software bugs, misconfigurations, and incorrect access controls
#
# https://kdd.ics.uci.edu/databases/kddcup99/task.html
