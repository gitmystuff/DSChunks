# %% [markdown]
# # Probability Distribution Tables
#
# https://www.statology.org/probability-distribution-table/
#
# F: 4<br />
# D: 6<br />
# C: 10<br />
# B: 7<br />
# A: 3<br />
#
# Columns: Grade, # in ea grade, prob of distribution, cum of distribution, weighted average, squared errors
#
# see notes
#
# https://www.analyticsvidhya.com/blog/2022/03/when-the-measurements-accuracy-misleads-you/
