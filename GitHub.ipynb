# %% [markdown]
# <a href="https://colab.research.google.com/github/gitmystuff/DSChunks/blob/main/GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GitHub

# %% [markdown]
# ## Overview
#
# * Github Basics
# * Python Module Template - Replit / VScode
# * HTML Basics

# %% [markdown]
# ## Installs
#
# * https://git-scm.com/
# * https://code.visualstudio.com/

# %% [markdown]
# ## GIT
#
# * SCM - Source Code Management - https://www.atlassian.com/git/tutorials/source-code-management
# * Version Control - https://en.wikipedia.org/wiki/Version_control
# * Revision Control - https://fullscale.io/blog/top-10-version-control-systems/
# * https://git-scm.com/
# * https://git-scm.com/book/en/v2
# * https://www.youtube.com/watch?v=HVsySz-h9r4

# %% [markdown]
# **Git**
#
# * **Version Control System:** At its core, Git is a tool that allows you to track changes to your files over time. Think of it like a super-powered "undo" button for your projects.
# * **Local:** Git is installed and runs on your own computer. It maintains a history of every change made to your project in a special database called a repository (or "repo" for short).
# * **Key Concepts:**
#     * **Repository:** A folder that Git tracks. It contains all your project files and the entire history of changes.
#     * **Commit:** A snapshot of your project at a specific point in time. You create a commit every time you want to save a set of changes.
#     * **Branch:**  Like a separate line of development. You can create branches to work on new features or experiments without affecting the main project.
#     * **Merge:** The process of combining changes from different branches.

# %% [markdown]
# ## What is GitHub?
#
# * An easy to use web service for version control and collaboration
# * Use GitHub to manage projects like software development, writing books and research papers, websites, quality control, resumes, portfolios, etc
#
# Sources
#
# * https://kinsta.com/knowledgebase/what-is-github/
# * https://github.com/topics/portfolio
# * https://github.com/topics/research-paper
# * https://ben.balter.com/2015/02/06/word-diff/

# %% [markdown]
# **GitHub**
#
# * **Online Platform:** GitHub is a website that provides hosting for Git repositories. It's like a central hub where you can store your code in the cloud.
# * **Collaboration:** GitHub makes it easy for multiple people to work on the same project. Developers can share code, track changes, and collaborate efficiently.
# * **Social Features:** GitHub has social elements like following other developers, starring interesting projects, and contributing to open-source software.
# * **Key Features:**
#     * **Pull requests:** A way to propose changes to a project. Others can review your code and provide feedback before it's merged.
#     * **Issues:** A system for tracking bugs, tasks, and feature requests.
#     * **Wikis:** A place to document your project and provide helpful information.

# %% [markdown]
# ## Hello World
#
# * https://docs.github.com/en/get-started/quickstart/hello-world

# %% [markdown]
# ## Create a Web Site from GitHub
#
# * https://github.com/Ovi/HTML-CSS-CV
# * https://startbootstrap.com/
# * https://github.com/topics/cv-template
# * https://docs.github.com/en/pages/getting-started-with-github-pages/configuring-a-publishing-source-for-your-github-pages-site

# %% [markdown]
# ## Code Editor
#
# * VSCode - https://code.visualstudio.com/
# * https://code.visualstudio.com/docs/introvideos/basics
# * https://code.visualstudio.com/docs/sourcecontrol/intro-to-git
# * https://www.freecodecamp.org/news/best-colorful-vscode-extensions-for-productivity/
# * https://www.freecodecamp.org/news/vs-code-extensions-to-increase-developer-productivity/
# * https://www.freecodecamp.org/news/how-to-use-markdown-in-vscode/

# %% [markdown]
# ## VSCode Extensions
#
# * https://www.kdnuggets.com/2022/07/12-essential-vscode-extensions-data-science.html
# * https://code.visualstudio.com/docs/datascience/overview
# * https://code.visualstudio.com/docs/sourcecontrol/github

# %% [markdown]
# ## Replit
#
# * https://www.freecodecamp.org/news/how-to-use-replit/

# %% [markdown]
# ## HTML Basics
#
# * https://replit.com/talk/learn/Full-HTML-Tutorial/78035

# %% [markdown]
# ## Integrate GitHub and Replit
#
# * https://docs.replit.com/category/using-git-on-replit
# * Personalize the html in your resume repository
#
# ### Reset
#
# * https://myunt-my.sharepoint.com/:w:/r/personal/cliff_whitworth_unt_edu/_layouts/15/Doc.aspx?sourcedoc=%7B92DB08C5-4F81-442E-AF40-FE4DBA6B0DFF%7D&file=resetting%20github%20and%20replit%20for%20resume.docx&action=default&mobileredirect=true
